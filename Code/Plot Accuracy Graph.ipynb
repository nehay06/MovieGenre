# %%
import matplotlib.pyplot as plt
import numpy as np
iter = [i for i in range(1,5)]
labels = ['Random Forest', 'AdaBoost' ,'MLP' ,'SVM']
#Genre3Labels
#Row1 LBP+MOMENT
#Row2 HSV+MOMENT
#Row3 SIFT+BOW
accuracy1 = [[0.591776798825,0.565834557024,0.547723935389,0.576113558492],
           [0.62212432697,0.57268722467,0.572197748409,0.547723935389],
           [0.433186490455,0.534508076358,0.542339696525,0.542339696525]
           ]

#SingleGenre
accuracy2 = [[0.472135007849,0.414442700157,0.436420722135,0.452119309262],
           [0.492935635793,0.459372056515, 0.449372056515,0.419152276295],
           [0.452119309262,0.399136577708, 0.387362637363,0.415620094192]
           ]

#MultiGenre
# accuracy = [[0.591776798825,0.565834557024,0.547723935389,0.576113558492],
#            [0.62212432697,0.57268722467,0.572197748409,0.547723935389],
#            [0.433186490455,0.534508076358,0.542339696525,0.542339696525]
#            ]

#BalancedGenre3
# accuracy3 = [[ 0.551111111111,0.512888888889,0.547723935389,0.499555555556],
#            [0.524444444444,0.512888888889, 0.497777777778,0.489555555556],
#            [0.433186490455,0.534508076358,0.542339696525,0.542339696525] - to be done
#            ]

#TopFulllGenre3
accuracy4 = [[0.551111111111,0.512888888889,0.547723935389,0.499555555556],
           [0.524444444444,0.512888888889,0.497777777778,0.489555555556],
           [0.413186490455,0.504508076358,0.512339696525,0.522339696525]
           ]

#TopFullGenreBalanced3.
# accuracy = [[0.591776798825,0.565834557024,0.547723935389,0.576113558492],
#            [0.62212432697,0.57268722467,0.572197748409,0.547723935389],
#            [0.433186490455,0.534508076358,0.542339696525,0.542339696525]
#            ]
fig, ax = plt.subplots()
ax.plot(iter, accuracy4[0], label = 'LBP+Moment')
ax.plot(iter, accuracy4[1], label = 'HSV+Moment')
ax.plot(iter, accuracy4[2], label = 'SIFT+BOW')

ax.set_xlabel('Classification Method')
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy vs Classifier')
legend = ax.legend(loc= 'lower right', shadow=True)
plt.xticks(iter, labels)
plt.savefig('./../Figures/Genre5Acc.png')  
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
iter = [i for i in range(1,7)]
labels = ['Dataset 1', 'Dataset 2' ,'Dataset 3' ,'Dataset 4','Dataset 5' ,'Dataset 6']
#Genre3Labels
#Row1 LBP+MOMENT
#Row2 HSV+MOMENT
#Row3 SIFT+BOW
accuracy1 = [[0.591776798825,0.565834557024,0.547723935389,0.576113558492],
           [0.62212432697,0.57268722467,0.572197748409,0.547723935389],
           [0.433186490455,0.534508076358,0.542339696525,0.542339696525]
           ]
fig, ax = plt.subplots()
ax.plot(iter, accuracy4[0], label = 'LBP+Moment')
ax.plot(iter, accuracy4[1], label = 'HSV+Moment')
ax.plot(iter, accuracy4[2], label = 'SIFT+BOW')

ax.set_xlabel('Classification Method')
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy vs Classifier')
legend = ax.legend(loc= 'lower right', shadow=True)
plt.xticks(iter, labels)
plt.savefig('./../Figures/Genre5Acc.png')  
plt.show()
